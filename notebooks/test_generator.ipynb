# %%
import sys
import os

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from src.generator.rag_generator import RAGGenerator

gen = RAGGenerator(model="llama3")

dummy_context = """
[BOOK 1]
Title: Book A
Author: Someone
Genres: Fantasy, Romance
Rating: 4.5
Description: A cozy fantasy romance...

[BOOK 2]
Title: Book B
Author: Another
Genres: Thriller
Rating: 4.2
Description: A dark thriller with twists...
"""

query = "I want a cozy fantasy romance with light vibes."

out = gen.generate(query=query, context=dummy_context)
print(out["answer"])
# Out:
# Based on your query for a cozy fantasy romance with light vibes, I highly recommend the following titles:
#
# 1. **Book A**: As you've already read the description of this book, it's a perfect match! It's a cozy fantasy romance, and its 4.5-star rating suggests that readers have enjoyed its lighthearted tone.
#
# Since the other book doesn't fit your desired genre (it's a thriller), I won't recommend it. Enjoy your cozy fantasy romance with Book A!

# %%
query = "Give me a dark academia standalone with atmospheric writing."

out = gen.generate(query=query, context=dummy_context)
print(out["answer"])
# Out:
# Based on your request for a dark academia standalone with atmospheric writing, I recommend the following:
#
# 1. **Book B**: This thriller has a dark tone and twists, which aligns well with the "dark academia" aspect of your query. While it's not explicitly labeled as an academic setting, the thriller genre often incorporates elements of mystery and suspense that might create an atmospheric sense.
# 2. None (since Book A is a fantasy romance, it doesn't fit the dark academia criteria)
#
# Since there are only two books in the retrieved list, I couldn't find another matching recommendation. If you'd like to expand your search or provide more context, I can try to help further!

# %%
query = "I loved Six of Crows and The Hunger Games, what next?"

out = gen.generate(query=query, context=dummy_context)
print(out["answer"])
# Out:
# Based on your love for Six of Crows (fantasy) and The Hunger Games (thriller), I'm recommending the following books from the retrieved list:
#
# 1. **Book A**: This cozy fantasy romance seems like a great match, as it shares some similarities with Six of Crows' fantasy elements and has a strong romantic aspect.
#
# 2. **(No thriller recommendation found)**: Unfortunately, none of the retrieved books fall into the thriller genre, which is similar to The Hunger Games. However, if you're open to exploring other genres or searching beyond these retrieved books, I can suggest some thrillers that might interest you!
#
# Let me know if you'd like more recommendations or have any specific preferences!

# %%
query = "I want something light, funny, slice-of-life with found family."

out = gen.generate(query=query, context=dummy_context)
print(out["answer"])
# Out:
# Based on your query for something light, funny, slice-of-life with found family, I recommend the following:
#
# 1. **Book A**: This book seems like a great fit as it's described as a "cozy fantasy romance" and has a 4.5-star rating, indicating a lighthearted and enjoyable read. The fantasy and romance genres also suggest a sense of wonder and connection between characters, which aligns with your desire for found family.
#
# Since the description doesn't explicitly mention slice-of-life or humor, I'm assuming that the book's tone might be more whimsical and romantic, rather than laugh-out-loud funny. However, it's still worth exploring if you're looking for a lighthearted read.
#
# No other books in the list seem to match your query well, as **Book B** is described as a dark thriller with twists, which doesn't align with your request for something light and funny.

# %%
query = "Give me a fantasy with political intrigue and minimal romance."

out = gen.generate(query=query, context=dummy_context)
print(out["answer"])
# Out:
# Based on your query for a fantasy book with political intrigue and minimal romance, I'm recommending the following:
#
# 1. **No recommendation from Book 1**, as it's primarily a fantasy romance and doesn't fit the query's requirements.
#
# 2. **Book B**: While it's not a traditional fantasy novel, Book B is a thriller that deals with twists and turns, which can be applied to political intrigue in a fantasy setting. The dark tone of the book might also contribute to the intrigue you're looking for.
#
# Unfortunately, since there are only two books provided, I won't be able to recommend more than one option.
